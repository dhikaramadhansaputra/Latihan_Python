# %%
a = 0

# %%
while a < 5:
    print(a)
    a = a+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a = 0
while a < 5:
    print(a)
    if a == 3:
        break
    a = a+1
# Out:
# 0
# 1
# 2
# 3

# %%
a = 0
while a < 5:
    print(a)
    a = a+1
else:
    print("y")
# Out:
# 0
# 1
# 2
# 3
# 4
# y
