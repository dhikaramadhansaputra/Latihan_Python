# %%
## Normal Function (simple)

# %%
def function_pertama():
    print("pertama")

# %%
function_pertama()
# Out:
# pertama

# %%
def parameter(number):
    print(number*2)

# %%
parameter(2)
# Out:
# 4

# %%
def luas_persegi(panjang, lebar):
    print(panjang*lebar)

# %%
luas_persegi(2,5)
# Out:
# 10

# %%
def a(*number):
    print(number[0]*number[1])

# %%
a(2,4,5,53)
# Out:
# 8

# %%
b = 42,2,4,5,6,2,4
def a(*number):
    print(number[0]+number[1])

# %%
a(*b)
# Out:
# 44

# %%
def a(panjang, lebar):
    print(panjang* lebar)

# %%
a(lebar = 2, panjang = 4)
# Out:
# 8

# %%
def kwarg(**number):
    print("My name is: "+ number['name']+ " Im " + number['age']+ " Years old")

# %%
kwarg(name = "Dhika", age = "21")
# Out:
# My name is: Dhika Im 21 Years old
