# %%
a = "Hello World"

print(a[:5])
# Out:
# Hello

# %%
a = "Hello World"
print(a[6])
# Out:
# W

# %%
a = "Hello World"
print(a[-1])
# Out:
# d

# %%
a = "Hello World"
print(a[:-3])
# Out:
# Hello Wo

# %%
a = "Hello World"
print(a[2:6])
# Out:
# llo

# %%
#list
[1,2,3]
# Out:
# [1, 2, 3]

# %%
["Strawbery", "Coklat", "Vanilla", 3, ["Scoops, Spoons"], 16, True]
# Out:
# ['Strawbery', 'Coklat', 'Vanilla', 3, ['Scoops, Spoons'], 16, True]

# %%
es_krim = ["Strawbery", "Coklat", "Vanilla", 3, ["Scoops, Spoons"], 16, True]

es_krim.append("Mangga")
print(es_krim)
# Out:
# ['Strawbery', 'Coklat', 'Vanilla', 3, ['Scoops, Spoons'], 16, True, 'Mangga']

# %%
es_krim[0] = "Stroberi"

print(es_krim)
# Out:
# ['Stroberi', 'Coklat', 'Vanilla', 3, ['Scoops, Spoons'], 16, True, 'Mangga']

# %%
es_krim[4][0]
# Out:
# 'Scoops, Spoons'

# %%
tuple = (1,2,3,4,5)

tuple[0]
# Out:
# 1

# %%
tuple.append(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 tuple.append(6)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
#set
a = {1,2,3}

# %%
type(a)
# Out:
# set

# %%
m = {1,2,3,4,1,2,31,3,3,13,2,3,1,2,13}
print(a)
# Out:
# Hello World

# %%
b = {1,3,4,8,7,8,9,987,8,89}

# %%
print(m & b)
# Out:
# {1, 3, 4}

# %%
print(m-b)
# Out:
# {2, 13, 31}

# %%
print(b-m)
# Out:
# {7, 8, 9, 89, 987}

# %%
print(m^b)
# Out:
# {2, 7, 8, 9, 13, 89, 987, 31}

# %%
cream ={
    'nama':'Dhika Ramadhan Saputra',
    'harian':5,
    'favorite':['Coklat', 'Vanilla']
}

# %%
type(cream)
# Out:
# dict

# %%
print(cream)
# Out:
# {'nama': 'Dhika Ramadhan Saputra', 'harian': 5, 'favorite': ['Coklat', 'Vanilla']}

# %%
cream.values()
# Out:
# dict_values(['Dhika Ramadhan Saputra', 5, ['Coklat', 'Vanilla']])

# %%
cream.keys()
# Out:
# dict_keys(['nama', 'harian', 'favorite'])

# %%
cream.items()
# Out:
# dict_items([('nama', 'Dhika Ramadhan Saputra'), ('harian', 5), ('favorite', ['Coklat', 'Vanilla'])])

# %%
cream['nama']
# Out:
# 'Dhika Ramadhan Saputra'

# %%
cream['nama'] = 'Valler Saputra'
cream['nama']
# Out:
# 'Valler Saputra'

# %%
cream.update({'berat':'100 Kg'})
print(cream)
# Out:
# {'nama': 'Valler Saputra', 'harian': 5, 'favorite': ['Coklat', 'Vanilla'], 'berat': '100 Kg'}

# %%
del cream['berat']
print(cream)
# Out:
# {'nama': 'Valler Saputra', 'harian': 5, 'favorite': ['Coklat', 'Vanilla']}
