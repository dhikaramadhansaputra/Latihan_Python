# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\Dhika Ramadhan Saputra\Data Analist\Kebutuhan\layoffs.csv")

# %%
df2 = pd.read_table(r"D:\Dhika Ramadhan Saputra\Data Analist\Kebutuhan\countries of the world.txt")

# %%
df3 = pd.read_json(r"D:\Dhika Ramadhan Saputra\Data Analist\Kebutuhan\json_sample.json")

# %%
df4 = pd.read_excel(r"D:\Dhika Ramadhan Saputra\Data Analist\Kebutuhan\Excel Charts Tutorial File.xlsx")

# %%
df
# Out:
#                             company          location         industry  \
# 0                         Atlassian            Sydney            Other
# 1                          SiriusXM     New York City            Media
# 2                            Alerzo            Ibadan           Retail
# 3                            UpGrad            Mumbai        Education
# 4                              Loft         Sao Paulo      Real Estate
# 5                     Embark Trucks       SF Bay Area   Transportation
# 6                             Lendi            Sydney      Real Estate
# 7                       UserTesting       SF Bay Area        Marketing
# 8                            Airbnb       SF Bay Area              NaN
# 9                          Accolade           Seattle       Healthcare
# 10                           Indigo            Boston            Other
# 11                          Zscaler       SF Bay Area         Security
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2361 entries, 0 to 2360
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   company                2361 non-null   object
#  1   location               2361 non-null   object
#  2   industry               2357 non-null   object
#  3   total_laid_off         1621 non-null   float64
#  4   percentage_laid_off    1576 non-null   float64
#  5   date                   2360 non-null   object
#  6   stage                  2355 non-null   object
#  7   country                2361 non-null   object
#  8   funds_raised_millions  2152 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 166.1+ KB

# %%
df.shape
# Out:
# (2361, 9)

# %%
df.head(10)
# Out:
#          company       location        industry  total_laid_off  \
# 0      Atlassian         Sydney           Other           500.0
# 1       SiriusXM  New York City           Media           475.0
# 2         Alerzo         Ibadan          Retail           400.0
# 3         UpGrad         Mumbai       Education           120.0
# 4           Loft      Sao Paulo     Real Estate           340.0
# 5  Embark Trucks    SF Bay Area  Transportation           230.0
# 6          Lendi         Sydney     Real Estate           100.0
# 7    UserTesting    SF Bay Area       Marketing            63.0
# 8         Airbnb    SF Bay Area             NaN            30.0
# 9       Accolade        Seattle      Healthcare             NaN
#
#    percentage_laid_off      date     stage        country  \
# 0                 0.05  3/6/2023  Post-IPO      Australia
# 1                 0.08  3/6/2023  Post-IPO  United States
# 2                  NaN  3/6/2023  Series B        Nigeria
# ...

# %%
df.tail(10)
# Out:
#                company        location        industry  total_laid_off  \
# 2351           Service     Los Angeles          Travel             NaN
# 2352      HopSkipDrive     Los Angeles  Transportation             8.0
# 2353       Panda Squad     SF Bay Area        Consumer             6.0
# 2354     Tamara Mellon     Los Angeles          Retail            20.0
# 2355          EasyPost  Salt Lake City       Logistics            75.0
# 2356         Blackbaud      Charleston           Other           500.0
# 2357             Yahoo     SF Bay Area        Consumer          1600.0
# 2358             Hibob        Tel Aviv              HR            70.0
# 2359            Casper   New York City          Retail             NaN
# 2360  Wildlife Studios       Sao Paulo        Consumer           300.0
#
#       percentage_laid_off        date     stage        country  \
# 2351                 1.00   3/16/2020      Seed  United States
# ...

# %%
df['company']
# Out:
# 0                           Atlassian
# 1                            SiriusXM
# 2                              Alerzo
# 3                              UpGrad
# 4                                Loft
# 5                       Embark Trucks
# 6                               Lendi
# 7                         UserTesting
# 8                              Airbnb
# 9                            Accolade
# 10                             Indigo
# 11                            Zscaler
# 12                        MasterClass
# 13                         Ambev Tech
# 14                              Fittr
# 15                               CNET
# 16                           Flipkart
# 17                            Kandela
# 18                      Truckstop.com
# 19                       Thoughtworks
# 20                              iFood
# 21                       Color Health
# 22                              Waymo
# 23                             PayFit
# 24                          Yellow.ai
# ...

# %%
df.loc[3]
# Out:
# company                     UpGrad
# location                    Mumbai
# industry                 Education
# total_laid_off               120.0
# percentage_laid_off            NaN
# date                      3/6/2023
# stage                      Unknown
# country                      India
# funds_raised_millions        631.0
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# company                     UpGrad
# location                    Mumbai
# industry                 Education
# total_laid_off               120.0
# percentage_laid_off            NaN
# date                      3/6/2023
# stage                      Unknown
# country                      India
# funds_raised_millions        631.0
# Name: 3, dtype: object
