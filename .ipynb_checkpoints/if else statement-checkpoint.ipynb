# %%
if 10 == 10 :
    print("ya")
# Out:
# ya

# %%
a = 10
b = 10

if a == b :
    print("ya")
# Out:
# ya

# %%
if a < b:
    print("if")
else:
    print("else")
# Out:
# else

# %%
a = 1
b = 5
c = b

if (b + c == b*2) and (b-1 == c-1):
    print("sama sama benar")
else:
    print("ada yang salah")
# Out:
# sama sama benar

# %%
a = 14,1,421,52,56,346,45,74,57,568,6,73,6243,41,35,34,645,7,45,634,52,5,4365,4,6754,7454,2,52,5,245,3,53,43,5,35,34,53,45,2,5,2,36,2,51,51
b = 234

if b in a:
    print("ada b di dalam a")
else:
    print("ga ada b di dalam a")
# Out:
# ga ada b di dalam a
