# %%
10 ==10
# Out:
# True

# %%
a = 10
b = 3
a == b
# Out:
# False

# %%
a = "aku"
b = "kita"

a < b
# Out:
# True

# %%
a = "aku"
b = 4

b==a
# Out:
# False

# %%
a = "sate ayam dibakar satu"

"sate" in a
# Out:
# True

# %%
a = [1,2,3,4,5]

b = 4

b not in a
# Out:
# False
