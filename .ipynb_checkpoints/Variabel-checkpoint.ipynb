# %% [markdown]
# Basic Variabel

# %%
a = "Nama "
b = "saya "
c = "Dhika."

print(a+b+c)
# Out:
# Nama saya Dhika.

# %%
a = 1
b = 3
c = 5

print(a+b+c)
# Out:
# 9

# %%
a = "Umur"
b = "saya"
c = 19
d = "tahun."

print(a,b,c,d)
# Out:
# Umur saya 19 tahun.

# %%
a=b=c= "Manusia"

print(c)
type(c)
# Out:
# Manusia
# str

# %% [markdown]
# List

# %%
rasa_es_krim = ["Vanilla", "Coklat", "Anggur"]

print(rasa_es_krim)
# Out:
# ['Vanilla', 'Coklat', 'Anggur']
